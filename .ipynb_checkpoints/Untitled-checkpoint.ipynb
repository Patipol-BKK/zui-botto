# %%
import os

import discord
import openai
import functools
import typing
import asyncio
from dotenv import load_dotenv
import datetime
import re
import tiktoken
import time

load_dotenv()
TOKEN = os.getenv('DISCORD_TOKEN')
GUILD = os.getenv('DISCORD_GUILD')

DEFAULT_PROMPT = os.getenv('DEFAULT_PROMPT')

openai.api_key = os.getenv("OPENAI_API_KEY")

intents = discord.Intents.default()
intents.message_content = True
intents.members = True

client = discord.Client(intents=intents)

# %%
@client.event
async def on_ready():
    for guild in client.guilds:
        if guild.name == GUILD:
            break

    print(
        f'{client.user} is connected to the following guild:\n'
        f'{guild.name}(id: {guild.id})'
    )

# %%
@client.event
async def on_message(message):
    if message.author.bot:
            return
    try:
        guild_id = message.guild.id
        if not ('bot' in str(message.channel) or 'gpt' in str(message.channel) or 'chat' in str(message.channel)):
            return
    except:
        guild_id = 'dm'
    channel = message.channel
    channel_id = message.channel.id

    intent_id = str(channel_id) + '_' + str(guild_id)
    global channel_intents
    if intent_id not in channel_intents:
        channel_intents[intent_id] = init_intent()
    print(f'{message.author}: {message.content}')

# %%
with open('test_text.txt') as f:
    test_text = f.read()

# %%
import re
import markdown
def find_codeblocks(text):
    idx_list = []
    for m in re.finditer('```', text):
        idx_list.append(m.start())
    return idx_list
            
def split_code_sections(text):
    codeblock_marker_indices = find_codeblocks(text)
    
find_codeblocks(test_text)
# Out:
# [562, 2195]

# %%
def separate_sections(article_string):
    sections = []
    pattern = r'(#{1,6}\s.*|>\s.*|\*.*|```[a-zA-Z]+\n[\s\S]*?\n```|`[\s\S]*?`|[\s\S]+?(?=#|\n>|\n\*|\n```|\n`))'
    matches = re.findall(pattern, article_string, re.MULTILINE | re.DOTALL)
    
    for match in matches:
        if match.startswith('#'):
            sections.append(('Heading', match.strip('#').strip()))
        elif match.startswith('>'):
            sections.append(('Block Quote', match.strip('> ').strip()))
        elif match.startswith('*'):
            sections.append(('List', match.strip('* ').strip()))
        elif match.startswith('```'):
            code_block = match.strip('`')
            language = code_block.split('\n', 1)[0].strip('`')
            code = code_block.split('\n', 1)[1].strip()
            code = code.replace('`', '\\`')
            sections.append(('Code Block', f'Language: {language}\n{code}'))
        elif match.startswith('`'):
            sections.append(('Inline Code', match.strip('`').replace('`', '\\`')))
        else:
            sections.append(('Text', match.strip()))
    
    return sections
markdown.markdown(test_text)
# Out:
# '<p>I apologize for the confusion. The <code>pytorch_tabular</code> library does not have a built-in option to specify metrics in the <code>TrainerConfig</code>. The metrics are automatically determined based on the task (classification or regression).</p>\n<p>For regression tasks, the loss function used is the Mean Squared Error (MSE), and the metrics reported are MSE and R2 Score. Unfortunately, there\'s no straightforward way to report the Root Mean Squared Error (RMSE) directly using <code>pytorch_tabular</code>.</p>\n<p>However, you can calculate RMSE manually after making predictions with the model:</p>\n<p>```python\nfrom pytorch_tabular import TabularModel\nfrom pytorch_tabular.models import CategoryEmbeddingModelConfig\nfrom pytorch_tabular.config import DataConfig, OptimizerConfig, TrainerConfig, ExperimentConfig\nfrom sklearn.metrics import mean_squared_error\nimport numpy as np</p>\n<h1>Assume we have a DataFrame \'df\' with categorical features \'cat\', numerical features \'num\' and target \'target\'</h1>\n<p>df = pd.DataFrame({\n    \'cat\': pd.Series([\'a\', \'b\', \'c\', \'a\'], dtype=\'category\'),\n    \'num\': [1, 2, 3, 4],\n    \'target\': [1.2, 3.4, 2.1, 4.3]\n})</p>\n<p>data_config = DataConfig(\n    target=[\'target\'],  # target should be a list even if you have only one target\n    continuous_cols=[\'num\'],\n    categorical_cols=[\'cat\'],\n    continuous_feature_transform="quantile_normal",\n    normalize_continuous_features=True\n)\ntrainer_config = TrainerConfig(\n    auto_lr_find=True,  # Runs the LRFinder to automatically derive a learning rate\n    batch_size=64,\n    max_epochs=100,\n    gpus=1  # index of the GPU to use. 0, means CPU\n)</p>\n<p>optimizer_config = OptimizerConfig()</p>\n<p>model_config = CategoryEmbeddingModelConfig(\n    task="regression",\n    layers="1024-512-512",  # Number of nodes in each layer\n    activation="LeakyReLU",  # Activation between each layers\n    learning_rate = 1e-3\n)</p>\n<p>tabular_model = TabularModel(\n    data_config=data_config,\n    model_config=model_config,\n    optimizer_config=optimizer_config,\n    trainer_config=trainer_config\n)</p>\n<p>tabular_model.fit(train=df, validation=df)</p>\n<h1>Make predictions</h1>\n<p>result = tabular_model.predict(df)</p>\n<h1>Calculate RMSE</h1>\n<p>rmse = np.sqrt(mean_squared_error(df[\'target\'], result[\'target\']))\nprint(\'RMSE:\', rmse)\n```</p>\n<p>In this example, after training the model and making predictions, we calculate the RMSE using <code>sklearn.metrics.mean_squared_error</code> and <code>numpy.sqrt</code>.</p>'

# %%
import re
import discord_markdown_ast_parser
with open('test_text.txt') as f:
    test_text = f.read()

def parse_text_segment(text_segment):
    node_type = 'TEXT'
    code_lang = ''
    parsed_text = ''
    # Markdown stylings
    if text_segment['node_type'] == 'TEXT':
        parsed_text = text_segment['text_content']
    elif text_segment['node_type'] == 'ITALIC':
        parsed_text = '_'
        for child in text_segment['children']:
            parsed_text += parse_text_segment(child)['text_content']
        parsed_text += '_'
    elif text_segment['node_type'] == 'BOLD':
        parsed_text = '**'
        for child in text_segment['children']:
            parsed_text += parse_text_segment(child)['text_content']
        parsed_text += '**'
    elif text_segment['node_type'] == 'UNDERLINE':
        parsed_text = '__'
        for child in text_segment['children']:
            parsed_text += parse_text_segment(child)['text_content']
        parsed_text += '__'
    elif text_segment['node_type'] == 'STRIKETHROUGH':
        parsed_text = '~~'
        for child in text_segment['children']:
            parsed_text += parse_text_segment(child)['text_content']
        parsed_text += '~~'
    elif text_segment['node_type'] == 'SPOILER':
        parsed_text = '||'
        for child in text_segment['children']:
            parsed_text += parse_text_segment(child)['text_content']
        parsed_text += '||'
    elif text_segment['node_type'] == 'CODE_INLINE':
        parsed_text = '`'
        for child in text_segment['children']:
            parsed_text += parse_text_segment(child)['text_content']
        parsed_text += '`'
        
    # Blocks
    elif text_segment['node_type'] == 'QUOTE_BLOCK':
        node_type = 'QUOTE_BLOCK'
        for child in text_segment['children']:
            parsed_text += parse_text_segment(child)['text_content']
    elif text_segment['node_type'] == 'CODE_BLOCK':
        node_type = 'CODE_BLOCK'
        try:
            code_lang = text_segment['code_lang']
        except:
            pass

        for child in text_segment['children']:
            parsed_text += parse_text_segment(child)['text_content']
            
    return {
        'node_type': node_type,
        'code_lang': code_lang,
        'text_content': parsed_text
    }

def segment_block(segment, pattern):
    split_segments = []
    double_split_indices = [0]
    
    text = segment['text_content']
    
    for m in re.finditer(pattern, text):
        double_split_indices.append(m.start())
    double_split_indices.append(len(text))
    for idx, split_idx in enumerate(double_split_indices):
        if idx < len(double_split_indices) - 1:
            split_segments.append({
                'node_type': segment['node_type'],
                'code_lang': segment['code_lang'],
                'text_content': text[double_split_indices[idx]: double_split_indices[idx + 1]]
                
            })

    return split_segments

def segment_block_by_length(segment, max_length):
    split_segments = []
    idx = 0
    text = segment['text_content']
    
    markdown_length = 0
    if segment['node_type'] == 'QUOTE_BLOCK':
        markdown_length += len('> ')
    elif segment['node_type'] == 'CODE_BLOCK':
        markdown_length += len('```')*2 + len(segment['code_lang'])
    
    while True:
        print(idx)
        if idx >= len(text):
            break
        else:
            split_segments.append({
                'node_type': segment['node_type'],
                'code_lang': segment['code_lang'],
                'text_content': text[idx:min(idx + max_length - markdown_length, len(text))]
            })
        idx += max_length - markdown_length
        
    print(split_segments)
    return split_segments

def merge_block(segment1, segment2):
    

def get_block_length(segment):
    length = len(segment['text_content'])
    if segment['node_type'] == 'QUOTE_BLOCK':
        length += len('> ')
    elif segment['node_type'] == 'CODE_BLOCK':
        length += len('```')*2 + len(segment['code_lang'])
        
    return length
        
def get_merged_block_length(segment1, segment2):
    length = len(segment1['text_content']) + len(segment2['text_content'])
    if segment1['node_type'] == 'QUOTE_BLOCK':
        length += len('> ')
    elif segment1['node_type'] == 'CODE_BLOCK':
        length += len('```')*2 + len(segment1['code_lang'])
        
    return length
    
def segment_markdown(text, max_length):
    # Segment text to blocks according to text or code/quote blocks
    text_segments = []
    try:
        markdown_segments = discord_markdown_ast_parser.parse_to_dict(text)
        add_newline = True
        for segment in markdown_segments:
            if segment['node_type'] == 'QUOTE_BLOCK' or segment['node_type'] == 'CODE_BLOCK':
                text_segments.append(parse_text_segment(segment))
                add_newline = True
            else: 
                if add_newline:
                    text_segments.append(parse_text_segment(segment))
                    add_newline = False
                else:
                    text_segments[-1]['text_content'] += parse_text_segment(segment)['text_content']
    except Exception as e:
        # If segmentation unsuccessful, fall back to treating text as a single normal text block
        print(e)
        text_segments.append({
            'node_type': 'TEXT',
            'code_lang': '',
            'text_content': text
        })
        
    # Segment text to smallest possible blocks
    trimmed_segments = []
    for segment in text_segments:
        sub_segments = segment_block(segment, '\n\n')
        for sub_segment in sub_segments:
#             print(sub_segment)
            trimmed_segments.append(sub_segment)
            
    # Add up blocks to make each of them the maximum size that's still under the max_length limit
    # Uses greedy to add up
    # if single block is too big, subsegment using single \n
    # if newlines don't work, subsegment using white space
    # if none works, chop the blocks disregarding anything
    maxed_segments = []
    cumulated_segment = {}
    cumulated_length = 0
    for segment in trimmed_segments:
        current_length = get_block_length(segment)
            
        if cumulated_segment == {}:
            cumulated_segment = {
                'node_type': segment['node_type'],
                'code_lang': '',
                'text_content': '',
            } 
        # if segment too long, subsegment using newline
        if current_length >= max_length:
            sub_segments = segment_block(segment, '\n')
            
            for sub_segment in sub_segments:
                current_length = get_block_length(sub_segment)
                
                # if segment too long, subsegment using space
                if current_length >= max_length:
                    sub2_segments = segment_block(sub_segment, ' ')
                    
                    for sub2_segment in sub2_segments:
                        current_length = get_block_length(sub2_segment)
                        
                        # if segment too long, subsegment disregarding whitespaces
                        if current_length >= max_length:
                            sub3_segments = segment_block_by_length(sub2_segment, max_length)
                            for sub3_segment in sub3_segments:
                                current_length = get_block_length(sub3_segment)
                                cumulated_length = current_length
                                maxed_segments.append(sub3_segment)
                                
                                print(current_length, sub3_segment)
                        elif cirrent_length + cumulated_length:
                            if 
                            print(current_length, sub2_segment)
                else:
                    print(current_length, sub_segment)
            
#         print(current_length, segment['text_content'])
            
    return trimmed_segments
markdown_segments = segment_markdown(test_text, 20)
# Out:
# 1 {'node_type': 'TEXT', 'code_lang': '', 'text_content': 'I'}
# 10 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' apologize'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' for'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 11 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' confusion.'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' The'}
# 18 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' `pytorch_tabular`'}
# 8 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' library'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' does'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' not'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' have'}
# 2 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' a'}
# 9 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' built-in'}
# 7 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' option'}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' to'}
# 8 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' specify'}
# 8 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' metrics'}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' in'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 17 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' `TrainerConfig`.'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' The'}
# 8 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' metrics'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' are'}
# 14 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' automatically'}
# 11 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' determined'}
# 6 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' based'}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' on'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' task'}
# 16 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' (classification'}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' or'}
# 13 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' regression).'}
# 0 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ''}
# 1 {'node_type': 'TEXT', 'code_lang': '', 'text_content': '\n'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': '\nFor'}
# 11 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' regression'}
# 7 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' tasks,'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' loss'}
# 9 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' function'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' used'}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' is'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' Mean'}
# 8 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' Squared'}
# 6 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' Error'}
# 7 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' (MSE),'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' and'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 8 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' metrics'}
# 9 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' reported'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' are'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' MSE'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' and'}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' R2'}
# 7 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' Score.'}
# 15 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' Unfortunately,'}
# 8 {'node_type': 'TEXT', 'code_lang': '', 'text_content': " there's"}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' no'}
# 16 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' straightforward'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' way'}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' to'}
# 7 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' report'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' Root'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' Mean'}
# 8 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' Squared'}
# 6 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' Error'}
# 7 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' (RMSE)'}
# 9 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' directly'}
# 6 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' using'}
# 19 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' `pytorch_tabular`.'}
# 0 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ''}
# 1 {'node_type': 'TEXT', 'code_lang': '', 'text_content': '\n'}
# 9 {'node_type': 'TEXT', 'code_lang': '', 'text_content': '\nHowever,'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' you'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' can'}
# 10 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' calculate'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' RMSE'}
# 9 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' manually'}
# 6 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' after'}
# 7 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' making'}
# 12 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' predictions'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' with'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 7 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' model:'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'from'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pytorch'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_tabular'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pytorch'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_tabular'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' import'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Tabular'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Model'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Tabular'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Model'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\nfrom'}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pytorch'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_tabular'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '.models'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pytorch'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_tabular'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '.models'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' import'}
# 0
# 8
# 16
# 24
# 32
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Categor'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'yEmbeddi'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ngModelC'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'onfig'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Categor'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'yEmbeddi'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ngModelC'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'onfig'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\nfrom'}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pytorch'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_tabular'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '.config'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pytorch'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_tabular'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '.config'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' import'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' DataCon'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'fig,'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' DataCon'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'fig,'}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Optimiz'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'erConfig'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ','}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Optimiz'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'erConfig'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ','}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Trainer'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Config,'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Trainer'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Config,'}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Experim'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'entConfi'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Experim'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'entConfi'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\nfrom'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' sklearn'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '.metrics'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' sklearn'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '.metrics'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' import'}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' mean_sq'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'uared_er'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ror'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' mean_sq'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'uared_er'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ror'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\nimport'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' numpy'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' as'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' np'}
# 12 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ''}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n#'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Assume'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' we'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' have'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' a'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' DataFra'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'me'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' DataFra'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'me'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'df'"}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' with'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' categor'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ical'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' categor'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ical'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' feature'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 's'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' feature'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 's'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'cat',"}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' numeric'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'al'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' numeric'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'al'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' feature'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 's'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' feature'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 's'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'num'"}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' and'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' target'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'target"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "'"}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'target"}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "'"}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\ndf'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' ='}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pd.Data'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Frame({'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pd.Data'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Frame({'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'cat':"}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pd.Seri'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "es(['a',"}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' pd.Seri'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "es(['a',"}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'b',"}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'c',"}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'a'],"}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " dtype='"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'category'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "'),"}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " dtype='"}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'category'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "'),"}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'num':"}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' [1,'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' 2,'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' 3,'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' 4],'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'target"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "':"}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': " 'target"}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "':"}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' [1.2,'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' 3.4,'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' 2.1,'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' 4.3]'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n})'}
# 12 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ''}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\ndata_co'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'nfig'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\ndata_co'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'nfig'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' ='}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' DataCon'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'fig('}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' DataCon'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'fig('}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' target='}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "['target"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "'],"}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' target='}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "['target"}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "'],"}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' #'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' target'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' should'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' be'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' a'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' list'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' even'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' if'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' you'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' have'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' only'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' one'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' target'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# 32
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' continu'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ous_cols'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "=['num']"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ','}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' continu'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ous_cols'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "=['num']"}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ','}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# 32
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' categor'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ical_col'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "s=['cat'"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '],'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' categor'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ical_col'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "s=['cat'"}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '],'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# 32
# 40
# 48
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' continu'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ous_feat'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ure_tran'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'sform="q'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'uantile_'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'normal",'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' continu'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ous_feat'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ure_tran'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'sform="q'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'uantile_'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'normal",'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# 32
# 40
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' normali'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ze_conti'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'nuous_fe'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'atures=T'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'rue'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' normali'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ze_conti'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'nuous_fe'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'atures=T'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'rue'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n)'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\ntrainer'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_config'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\ntrainer'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_config'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' ='}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Trainer'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Config('}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Trainer'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Config('}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' auto_lr'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_find=Tr'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ue,'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' auto_lr'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_find=Tr'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ue,'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' #'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Runs'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' the'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' LRFinde'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'r'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' LRFinde'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'r'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' to'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' automat'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ically'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' automat'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ically'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' derive'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' a'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' learnin'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' learnin'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' rate'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' batch_s'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ize=64,'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' batch_s'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ize=64,'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' max_epo'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'chs=100,'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' max_epo'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'chs=100,'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' gpus=1'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' #'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' index'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' of'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' the'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' GPU'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' to'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' use.'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' 0,'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' means'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' CPU'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n)'}
# 12 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ''}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\noptimiz'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'er_confi'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\noptimiz'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'er_confi'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' ='}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Optimiz'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'erConfig'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '()'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Optimiz'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'erConfig'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '()'}
# 12 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ''}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\nmodel_c'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'onfig'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\nmodel_c'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'onfig'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' ='}
# 0
# 8
# 16
# 24
# 32
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Categor'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'yEmbeddi'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ngModelC'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'onfig('}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Categor'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'yEmbeddi'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ngModelC'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'onfig('}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' task="r'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'egressio'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'n",'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' task="r'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'egressio'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'n",'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' layers='}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '"1024-51'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '2-512",'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' layers='}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '"1024-51'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '2-512",'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' #'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Number'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' of'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' nodes'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' in'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' each'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' layer'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' activat'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ion="Lea'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'kyReLU",'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' activat'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ion="Lea'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'kyReLU",'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' #'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Activat'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ion'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Activat'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ion'}
# 0
# 8
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' between'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' between'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' each'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' layers'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' learnin'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g_rate'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' learnin'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g_rate'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' ='}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' 1e-3'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n)'}
# 12 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ''}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\ntabular'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_model'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\ntabular'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_model'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' ='}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Tabular'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Model('}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Tabular'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'Model('}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# 32
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' data_co'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'nfig=dat'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'a_config'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ','}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' data_co'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'nfig=dat'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'a_config'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ','}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# 32
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' model_c'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'onfig=mo'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'del_conf'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ig,'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' model_c'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'onfig=mo'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'del_conf'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ig,'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# 32
# 40
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' optimiz'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'er_confi'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g=optimi'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'zer_conf'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ig,'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' optimiz'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'er_confi'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'g=optimi'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'zer_conf'}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ig,'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' '}
# 0
# 8
# 16
# 24
# 32
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' trainer'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_config='}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'trainer_'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'config'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' trainer'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_config='}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'trainer_'}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'config'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n)'}
# 12 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ''}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 0
# 8
# 16
# 24
# 32
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\ntabular'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_model.f'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'it(train'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '=df,'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\ntabular'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_model.f'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'it(train'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '=df,'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' validat'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ion=df)'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' validat'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ion=df)'}
# 12 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ''}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n#'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Make'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' predict'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ions'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' predict'}
# 16 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'ions'}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\nresult'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' ='}
# 0
# 8
# 16
# 24
# 32
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' tabular'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_model.p'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'redict(d'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'f)'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' tabular'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '_model.p'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'redict(d'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'f)'}
# 12 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ''}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n#'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Calcula'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'te'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' Calcula'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'te'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' RMSE'}
# 17 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\nrmse'}
# 14 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' ='}
# 0
# 8
# 16
# 24
# 32
# 40
# 48
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' np.sqrt'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '(mean_sq'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'uared_er'}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "ror(df['"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "target']"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ','}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' np.sqrt'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '(mean_sq'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': 'uared_er'}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "ror(df['"}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "target']"}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ','}
# 0
# 8
# 16
# 24
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' result['}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "'target'"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ']))'}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' result['}
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "'target'"}
# 15 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ']))'}
# 0
# 8
# 16
# [{'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "\nprint('"}, {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "RMSE:',"}]
# 20 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "\nprint('"}
# 19 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': "RMSE:',"}
# 18 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': ' rmse)'}
# 13 {'node_type': 'CODE_BLOCK', 'code_lang': 'python', 'text_content': '\n'}
# 0 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ''}
# 1 {'node_type': 'TEXT', 'code_lang': '', 'text_content': '\n'}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': '\nIn'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' this'}
# 9 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' example,'}
# 6 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' after'}
# 9 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' training'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 6 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' model'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' and'}
# 7 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' making'}
# 13 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' predictions,'}
# 3 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' we'}
# 10 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' calculate'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' the'}
# 5 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' RMSE'}
# 6 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' using'}
# 0
# 20
# 40
# [{'node_type': 'TEXT', 'code_lang': '', 'text_content': ' `sklearn.metrics.me'}, {'node_type': 'TEXT', 'code_lang': '', 'text_content': 'an_squared_error`'}]
# 20 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' `sklearn.metrics.me'}
# 17 {'node_type': 'TEXT', 'code_lang': '', 'text_content': 'an_squared_error`'}
# 4 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' and'}
# 14 {'node_type': 'TEXT', 'code_lang': '', 'text_content': ' `numpy.sqrt`.'}
